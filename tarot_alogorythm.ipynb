# %%
import random
from transformers import AutoModelForSeq2SeqLM, AutoTokenizer

# %%
#1 the fool up
#2 the fool down
#3 the magician up
#4 the magician down
#5 high priestess up
#6 high priestess down
#7 the mepress up
#8 the mepress down
#9 the emperror up
#10 the emperror down
#11 the hierophant up
#12 the hierophant down
#13 the lovers up
#14 the lovers up
#15 chariot up
#16 chariot down
#17 strength up
#18 strength down
#19 hermit up
#20 hermit down
#21 wheel of fortune up
#22 wheel of fortune down
#23 justice
#24 justice
#25 hanged man
#26 hanged man
#27 death
#28 death
#29 temperance
#30 temperance
#31 devil
#32 devil
#33 tower
#34 tower
#35 star
#36 star
#37 moon
#38 moon
#39 sun
#40 sun
#41 judgemwent
#42 judgemwent
#43 world
#44 world
#45 knight of wands
#46 knight of wands
#47 king of wands
#48 king of wands
#49 queen of wands
#50 queen of wands
#51 page of wands
#52 page of wands
#53 two of wands
#54 two of wands
#55 three of wands
#56 three of wands
#57 five of wands
#58 five of wands
#59 six of wands
#60 six of wands
#61 eight of wands
#62 eight of wands
#63 nine of wands
#64 nine of wands
#65 ten of wands
#66 ten of wands
#67 ace of wands
#68 ace of wands
#69 4 of wands 
#70 4 of wands 
#71 7 of wands
#72 7 of wands
#73 ace of cups
#74 ace of cups
#75 two cups
#76 two cups
#77 3 cups
#78 3 cups
#79 4 cups
#80 4 cups
#81 5 cups
#82 5 cups
#83 6 cups
#84 6 cups
#85 7 of cups
#86 7 of cups
#87 8 of cups
#88 8 of cups
#89 9 of cups
#90 9 of cups
#91 10 of cups
#92 10 of cups
#93 page of cups
#94 page of cups
#95 knight of cups
#96 knight of cups
#97 queen of cups
#98 queen of cups
#99 king of cups
#100 king of cups
#101 king of swords
#102 king of swords
#103 queen of swords
#104 queen of swords
#105 page of swords
#106 page of swords
#107 ten of swords
#108 ten of swords
#109 nine of swrods
#110 nine of swrods
#111 eight of swords
#112 eight of swords
#113 secen of swords
#114 seven of swords
#115 six of swords
#116 six of swords
#117 five of swords
#118 five pf swords
#119 three of swords
#120 three of swords
#121 four of swords
#122 four of swords
#123 two of swords
#124 two of swords
#125 ace of swords
#126 ace of swords
#127 king of pentacles
#128 king of pentacles
#129 queen of pentacles
#130 queen of pentacles
#131 knight of pentacles
#132 knight of pentacles
#133 page of pentacles
#134 page of pentacles
#135 ten of pentacles 
#136 ten of pentacles 
#137 nine of pentacles
#138 nine of pentacles
#139 eight of pentacles
#140 eight of pentacles
#141 seven of pentacles
#142 seven of pentacles
#143 six of pentacles
#144 six of pentacles
#145 five of pentacles
#146 five of pentacles
#147 four of pentacles
#148 four of pentacles
#149 three of pentacles
#150 three of pentacles
#151 two of pentacles
#152 two of pentacles

# %%
class Wodoo_version_good():

    def __init__(self):
        self.dictionary = {"1":"beginnings, freedom, innocence, originality, adventure, idealism, spontaneity",
              "2":"reckless, careless, distracted, naive, foolish, gullible, stale, dull",
              "3":"willpower, desire, being resourceful,, skill, ability, concentration, manifestation",
              "4":"manipulation, cunning, trickery, wasted talent, illusion, deception",
              "5":"unconscious, intuition, mystery, spirituality, higher power, inner voice",
              "6":"repressed intuition, hidden motives, superficiality, confusion, cognitive dissonance",
              "7":"divine feminine, sensuality, fertility, nurturing, creativity, beauty, abundance, nature",
              "8":"insecurity, overbearing, negligence, smothering, lack of growth, lack of progress",
              "9":"stability, structure, protection, authority, control, practicality, focus, discipline",
              "10":"tyrant, domineering, rigid, stubborn, lack of discipline, recklessness",
              "11":"tradition, social groups, conventionality, conformity, education, knowledge, beliefs",
              "12":"rebellion, unconventionality, non-conformity, new methods, ignorance",
              "13":"love, unions, partnerships, relationships, choices, romance, balance, unity",
              "14":"disharmony, imbalance, conflict, detachment, bad choices, indecision",
              "15":"success, ambition, determination, willpower, control, self-discipline, focus",
              "16":"forceful, no direction, no control, powerless, aggression, obstacles",
              "17":"courage, bravery, confidence, compassion, self-confidence, inner power",
              "18":"self-doubt, weakness, low confidence, inadequacy, cowardice, forcefulness",
              "19":"self-reflection, introspection, contemplation, withdrawal, solitude, search for self",
              "20":"loneliness, isolation, recluse, being anti-social, rejection, returning to society",
              "21":"change, cycles, fate, decisive moments, luck, fortune, unexpected events",
              "22":"bad luck, lack of control, clinging to control, unwelcome changes, delays",
              "23":"justice, karma, consequence, accountability, law, truth, honesty, integrity, cause and effect",
              "24":"injustice, retribution, dishonesty, corruption, dishonesty, unfairness, avoiding accountability",
              "25":"sacrifice, waiting, uncertainty, lack of direction, perspective, contemplation",
              "26":"stalling, disinterest, stagnation, avoiding sacrifice, standstill, apathy",
              "27":"transformation, endings, change, transition, letting go, release",
              "28":"fear of change, repeating negative patterns, resisting change, stagnancy, decay",
              "29":"balance, peace, patience, moderation, calm, tranquillity, harmony, serenity",
              "30":"imbalance, excess, extremes, discord, recklessness, hastiness",
              "31":"oppression, addiction, obsession, dependency, excess, powerlessness, limitations",
              "32":"independence, freedom, revelation, release, reclaiming power, reclaiming control",
              "33":"disaster, destruction, upheaval, trauma, sudden change, chaos",
              "34":"averting disaster, delaying the inevitable, resisting change",
              "35":"hope, inspiration, positivity, faith, renewal, healing, rejuvenation",
              "36":"hopelessness, despair, negativity, lack of faith, despondent",
              "37":"illusion, intuition, uncertainty, confusion, complexity, secrets, unconscious",
              "38":"fear, deception, anxiety, misunderstanding, misinterpretation, clarity, understanding",
              "39":"illusion, intuition, uncertainty, confusion, complexity, secrets, unconscious",
              "40":"fear, deception, anxiety, misunderstanding, misinterpretation, clarity, understanding",
              "41":"self-evaluation, awakening, renewal, purpose, reflection, reckoning",
              "42":"self-doubt, lack of self-awareness, failure to learn lessons, self-loathing",
              "43":"completion, achievement, fulfilment, sense of belonging, wholeness, harmony",
              "44":"lack of closure, lack of achievement, feeling incomplete, emptiness",
              "45":"courageous, energetic, charming, hero, rebellious, hot tempered, free spirit",
              "46":"arrogant, reckless, impatient, lack of self control, passive, volatile, domineering",
              "47":"leadership, vision, big picture, taking control, daring decisions, boldness, optimism",
              "48":"forceful, domineering, tyrant, vicious, powerless, ineffective, weak leader",
              "49":"confident, self-assured, passionate, determined, social, charismatic, vivacious, optimistic",
              "50":"demanding, vengeful, low confidence, jealous, selfish, temperamental, bully",
              "51":"adventure, excitement, fresh ideas, cheerfulness, energetic, fearless, extroverted",
              "52":"hasty, impatient, lacking ideas, tantrums, laziness, boring, unreliable, distracted",
              "53":"planning, first steps, making decisions, leaving comfort, taking risks",
              "54":"bad planning, overanalyzing, not taking action, playing it safe, avoiding risk",
              "55":"momentum, confidence, expansion, growth, foresight, looking ahead",
              "56":"restriction, limitations, lack of progress, obstacles, delays, frustration",
              "57":"conflict, competition, arguments, aggression, tension, rivals, clashes of ego",
              "58":"end of conflict, cooperation, agreements, truces, harmony, peace, avoiding conflict",
              "59":"success, victory, triumph, rewards, recognition, praise, acclaim, pride",
              "60":"failure, lack of recognition, no rewards, lack of achievement",
              "61":"movement, speed, progress, quick decisions, sudden changes, excitement",
              "62":"waiting, slowness, chaos, delays, losing momentum, hastiness, being unprepared",
              "63":"last stand, persistence, grit, resilience, perseverance, close to success, fatigue",
              "64":"stubbornness, rigidity, defensiveness, refusing compromise, giving up",
              "65":"burden, responsibility, duty, stress, obligation, burning out, struggles",
              "66":"failure to delegate, shouldering too much responsibility, collapse, breakdown",
              "67":"inspiration, creative spark, new initiative, new passion, enthusiasm, energy",
              "68":"delays, blocks, lack of passion, lack of energy, hesitancy, creative blocks",
              "69":"community, home, celebrations, reunions, parties, gatherings, stability, belonging",
              "70":"lack of support, instability, feeling unwelcome, transience, lack of roots, home conflict",
              "71":"protectiveness, standing up for yourself, defending yourself, protecting territory",
              "72":"giving up, admitting defeat, yielding, lack of self belief, surrender",
              "73":"love, new feelings, emotional awakening, creativity, spirituality, intuition",
              "74":"coldness, emptiness, emotional loss, blocked creativity, feeling unloved, gloominess",
              "75":"unity, partnership, attraction, connection, close bonds, joining forces, mutual respect",
              "76":"separation, rejection, division, imbalance, tension, bad communication, withdrawal",
              "77":"friendship, community, gatherings, celebrations, group events, social events",
              "78":"gossip, scandal, excess, isolation, loneliness, solitude, imbalanced social life",
              "79":"apathy, contemplation, feeling disconnected, melancholy, boredom, indifference, discontent",
              "80":"clarity, awareness, acceptance, choosing happiness, depression, negativity",
              "81":"loss, grief, disappointment, sadness, mourning, discontent, feeling let down",
              "82":"acceptance, moving on, finding peace, contentment, seeing positives",
              "83":"nostalgia, memories, familiarity, healing, comfort, sentimentality, pleasure",
              "84":"stuck in past, moving forward, leaving home, independence",
              "85":"choices, searching for purpose, illusion, fantasy, daydreaming, wishful thinking, indecision",
              "86":"lack of purpose, disarray, confusion, diversion, distractions, clarity, making choices",
              "87":"abandonment, walking away, letting go, searching for truth, leaving behind",
              "88":"stagnation, monotony, accepting less, avoidance, fear of change, staying in bad situation",
              "89":"wishes coming true, contentment, satisfaction, success, achievements, recognition, pleasure",
              "90":"unhappiness, lack of fulfilment, disappointment, underachievement, arrogance, snobbery",
              "91":"happiness, homecomings, fulfillment, emotional stability, security, domestic harmony",
              "92":"unhappy home, separation, domestic conflict, disharmony, isolation​",
              "93":"idealism, sensitivity, dreamer, naivete, innocence, inner child, head in the clouds",
              "94":"emotional vulnerability, immaturity, neglecting inner child, escapism, insecurity",
              "95":"idealist, charming, artistic, graceful, tactful, diplomatic, mediator, negotiator",
              "96":"disappointment, tantrums, moodiness, turmoil, avoiding conflict, vanity",
              "97":"compassion, warmth, kindness, intuition, healer, counsellor, supportive",
              "98":"insecurity, giving too much, overly-sensitive, needy, fragile, dependence, martyrdom",
              "99":"wise, diplomatic, balance between head and heart, devoted, advisor, counsellor",
              "100":"overwhelmed, anxious, cold, repressed, withdrawn, manipulative, selfish",
              "101":"assertive, direct, impatient, intellectual, daring, focused, perfectionist, ambitious",
              "102":"rude, tactless, forceful, bully, aggressive, vicious, ruthless, arrogant",
              "103":"honest, independent, principled, fair, constructive criticism, objective, perceptive",
              "104":"pessimistic, malicious, manipulative, harsh, bitter, spiteful, cruel, deceitful, unforgiving",
              "105":"curious, witty, chatty, communicative, inspired, vigilant, alert, mental agility",
              "106":"scatterbrained, cynical, sarcastic, gossipy, insulting, rude, lack of planning",
              "107":"ruin, failure, bitterness, collapse, exhaustion, dead end, victimization, betrayal",
              "108":"survival, improvement, healing, lessons learned, despair, relapse",
              "109":"fear, anxiety, negativity, breaking point, despair, nightmares, isolation",
              "110":"recovery, learning to cope, facing life, finding help, shame, guilt, mental health issues",
              "111":"trapped, restricted, victimised, paralysed, helpless, powerless, imprisonment",
              "112":"freedom, release, taking control, survivor, facing fears, empowered, surrender",
              "113":"lies, trickery, scheming, strategy, resourcefulness,sneakiness, cunning",
              "114":"confession, conscience, regret, maliciousness, truth revealed",
              "115":"moving on, departure, leaving behind, distance, accepting lessons",
              "116":"stuck in past, returning to trouble, running away from problems, trapped",
              "117":"arguments, disputes, aggression, bullying, intimidation, conflict, hostility, stress",
              "118":"reconciliation, resolution, compromise, revenge, regret, remorse, cutting losses",
              "119":"heartbreak, separation, sadness, grief, sorrow, upset, loss, trauma, tears",
              "120":"healing, forgiveness, recovery, reconciliation, repressing emotions",
              "121":"rest, relaxation, peace, sanctuary, recuperation, self-protection, rejuvenation",
              "122":"recovery, awakening, re-entering world, release from isolation, restlessness, burnout",
              "123":"stalemate, difficult choices, stuck in the middle, denial, hidden information",
              "124":"indecision, hesitancy, anxiety, too much information, no right choice, truth revealed",
              "125":"clarity, breakthrough, new idea, concentration, vision, force, focus, truth",
              "126":"confusion, miscommunication, hostility, arguments, destruction, brutality",
              "127":"abundance, prosperity, security, ambitious, safe, kind, patriarchal, protective, businessman, provider, sensual, reliable",
              "128":"greed, materialistic, wasteful, chauvanist, poor financial decisions, gambler, exploitative, possessive",
              "129":"generous, caring, nurturing, homebody, good business sense, practical, comforting, welcoming, sensible, luxurious",
              "130":"selfish, unkempt, jealous, insecure, greedy, materialistic, gold digger, intolerant, self-absorbed, envious",
              "131":"practical, reliable, efficient, stoic, slow and steady, hard-working, committed, patient, conservative",
              "132":"workaholic, laziness, dull, boring, no initiative, cheap, irresponsible, gambler, risky investments",
              "133":"ambitious, diligent, goal oriented, planner, consistent, star student, studious, grounded, loyal, faithful, dependable",
              "134":"foolish, immature, irresponsible, lazy, underachiever, procrastinator, missed chances, poor prospects",
              "135":"legacy, roots, family, ancestry, inheritance, windfall, foundations, privilege, affluence, stability, tradition",
              "136":"family disputes, bankruptcy, debt, fleeting success, conflict over money, instability, breaking traditions",
              "137":"rewarded efforts, success, achievement, independence, leisure, material security, self-sufficiency",
              "138":"being guarded, living beyond means, material instability, reckless spending, superficiality",
              "139":"skill, talent, craftsmanship, quality, high standards, expertise, mastery, commitment, dedication, accomplishment",
              "140":"lack of quality, rushed job, bad reputation, lack of motivation, mediocrity, laziness, low skill, dead-end job",
              "141":"harvest, rewards, results, growth, progress, perseverance, patience, planning",
              "142":"unfinished work, procrastination, low effort, waste, lack of growth, setbacks, impatience, lack of reward",
              "143":"generosity, charity, community, material help, support, sharing, giving and receiving, gratitude",
              "144":"power dynamics, abuse of generosity, strings attached gifts, inequality, extortion",
              "145":"hardship, loss, isolation, feeling abandoned, adversity, struggle, unemployment, alienation, disgrace",
              "146":"positive changes, recovery from loss, overcoming adversity, forgiveness, feeling welcomed",
              "147":"possessiveness, insecurity, hoarding, stinginess, stability, security, savings, materialism, wealth, frugality, boundaries, guardedness",
              "148":"generosity, giving, spending, openness, financial insecurity, reckless spending",
              "149":"teamwork, shared goals, collaboration, apprenticeship, effort, pooling energy",
              "150":"lack of cohesion, lack of teamwork, apathy, poor motivation, conflict, ego, competition",
              "151":"balancing resources, adaptation, resourcefulness, flexibility, stretching resources",
              "152":"imbalance, unorganized, overwhelmed, messiness, chaos, overextending",
              "153":"new opportunities, resources, abundance, prosperity, security, stability, manifestation",
              "154":"missed chances, scarcity, deficiency, instability, stinginess, bad investments",
              }
    
  
    def generator(self):
        
        gen0 = random.randint(0,154)
        gen1 = random.randint(0,154)

        if gen1 == gen0:
            gen1 = random.randint(0,154)

        gen2 = random.randint(0,154)

        if gen1 == gen2:
            gen2 = random.randint(0,154)

        # print(self.dictionary[f"{gen0}"] + "\n" + "\n" + self.dictionary[f"{gen1}"] +"\n" + "\n" + self.dictionary[f"{gen2}"] + "\n")
        result = self.dictionary[f"{gen0}"]
        # version for t5 flan 
        # return self.dictionary[f"{gen0}"]        
        return result

# %%
x = Wodoo_version_good()

# %%
model = AutoModelForSeq2SeqLM.from_pretrained('google/flan-t5-large')

tokenizer = AutoTokenizer.from_pretrained('google/flan-t5-large')

task = "Question Answering"

# %%
text = str(x.generator())

# %%
text
# Out:
# 'adventure, excitement, fresh ideas, cheerfulness, energetic, fearless, extroverted'

# %%
# text = str(text)

# %%
# type(text)

# %%
if task == "Question Answering":
  input_text = "Generate text based future prediction on the symbolic meaning of " + text
  input_ids = tokenizer(input_text, return_tensors='pt').input_ids
  outputs = model.generate(input_ids, \
                         min_length=125, \
                         max_new_tokens=250, \
                         length_penalty = 2, \
                         num_beams=16, \
                         no_repeat_ngram_size=2, \
                         #num_return_sequences =2 \
                         early_stopping=True)

# %%
print(tokenizer.decode(outputs[0], skip_special_tokens=True))
# Out:
# if you want to succeed in your life, you need to be adventurous, energetic, fearless and extroverted. If you are a person who likes adventure, excitement, fresh ideas and cheerfulness, then you will be able to achieve your goals in the shortest time possible. You will also have the courage to try new things and new ways of thinking, which will help you to overcome your fear of failure and failures, and to become the best person you can be at the same time. The most important thing in life is not to worry about what others think about you, but to live life to the fullest.
